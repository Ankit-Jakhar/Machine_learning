# %%
#Feature engineering --> technique that is used for data preprocessing
#standredization -->

# %%
#Normal distribution -->
#central tendency(mean ,median ,mode)
#mean and meadian used for average ,
#outlaiers that value who are flacatued the average after 
#mode--> most frequent valuez
