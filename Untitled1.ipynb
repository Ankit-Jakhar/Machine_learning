# %%
import numpy as np

# %%
import pandas as pd

# %%
df =pd.read_csv("userbehaviour (1).csv")

# %%
df.head()
# Out:
#    userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0    1001                 17.0                       634.0            1
# 1    1002                  0.0                        54.0            0
# 2    1003                 37.0                       207.0            0
# 3    1004                 32.0                       445.0            1
# 4    1005                 45.0                       427.0            1
#
#    Ratings  New Password Request  Last Visited Minutes       Status
# 0        9                     7                  2990    Installed
# 1        4                     8                 24008  Uninstalled
# 2        8                     5                   971    Installed
# 3        6                     2                   799    Installed
# 4        5                     6                  3668    Installed

# %%
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
pio.templates.default ='plotly_white'

# %% [markdown]
# # Lets start by looking at the highest , lowest  and average screen time of all users

# %%
print(f"aversge screen time " ={df["average screen time"].mean()}")
print(f"highiest screen time " ={df["average screen time"].max()}")
print(f"lowes screen time " ={df["average screen time"].min()}")
# Out:
#   Cell In[12], line 1
#     print(f"aversge screen time " ={df["average screen time"].mean()}")
#                                                                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# # now lets have a look at the highist , loweest  and the average amount
# spent by all the users

# %%
print(f"average spent of the users " ={df["average spent on the app"]})
# Out:
#   Cell In[13], line 1
#     print(f"average spent of the users " ={df["average spent on the app"]})
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %% [markdown]
# # now lets have a look at thebrelationship between spending capacity and screen time
# of the active users and the users who have unistalled the app

# %%
figure =px.scatter(data_frame =df,
                  x ="Average screen time "
                  y ="average spent on the app(INR)" ,
                  size ="average spent on the app (INR)")
# Out:
#   Cell In[14], line 2
#     x ="Average screen time "
#        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# # now lets have a look at the relationship between the ratings given by the users and the average screen time

# %%
figure =px.scatter(data_frame =df ,
                  x ="average screen time" ,
                  y ="Ratings" ,
                  size ="Ratings")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 figure =px.scatter(data_frame =df ,
#       2                   x ="average screen time" ,
#       3                   y ="Ratings" ,
#       4                   size ="Ratings")
#
# ...

# %% [markdown]
# #

# %% [markdown]
# clustering_data =df[["average screen time " , "left_review " , "ratings" , "last_visited_minutes
# " , average spent on the app(INR) , "new_password_request"]]

# %%
clustering_data =df[["average screen time " , "left_review " , "ratings" , "last_visited_minutes 
" , average spent on the app(INR) , "new_password_request"]]
# Out:
#   Cell In[19], line 1
#     clustering_data =df[["average screen time " , "left_review " , "ratings" , "last_visited_minutes
#                                                                                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
from sklearn.preprocessing import MinMaxScaler
for i in clustring_data.columns:
    MinMaxScaler(i)

from sklearn.cluster import Kmeans 
KMeans =Kmeans.fit_predict(clustring_data)
df["segments" ] =clusters
print(df.head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 from sklearn.preprocessing import MinMaxScaler
# ----> 2 for i in clustring_data.columns:
#       3     MinMaxScaler(i)
#       5 from sklearn.cluster import Kmeans
#
# NameError: name 'clustring_data' is not defined

# %%
print(df["segments"]. value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Advanced python by saurab sir\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'segments'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(df["segments"]. value_counts())
#
# ...

# %% [markdown]
# # now lets rename the segments for a better understanding

# %%
df["segments"] =df["segments"].map{0:"Retained" , 1:"churn"  ,2:"needs attention"}
# Out:
#   Cell In[22], line 1
#     df["segments"] =df["segments"].map{0:"Retained" , 1:"churn"  ,2:"needs attention"}
#                                       ^
# SyntaxError: invalid syntax

# %%
PLOT =go.figure()
for i in list(df["segments"].unique()):


    PLOT.add_trace(go.scatter(x =df[df["segments"]==i]["last visited minutes "] ,
                            y =df[df["segments"] ==i]["Average spent on the app(INR)"] 
                             ,mode ="marker " , marker_size =6 , marker_line_width =1
                             
                             name =str(i)))

plot.update.traces(hovertemplate) ="last visited minutes: %x <br> averrage spent on the app(INR):%(Y)")


plot.update_layout(width =800 , height =800 , autosize =True , showlegend =True , 
                  yaxixtitle ="average spent on the app(INR)"
            ,     xaxixtitle ="last visited minutes" ,
                  )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 PLOT =go.figure()
#
# File ~\Advanced python by saurab sir\anaconda3\Lib\site-packages\plotly\graph_objects\__init__.py:299, in __getattr__(import_name)
#     295         from ..missing_ipywidgets import FigureWidget
#     297         return FigureWidget
# --> 299 return orig_getattr(import_name)
#
# File ~\Advanced python by saurab sir\anaconda3\Lib\site-packages\_plotly_utils\importers.py:39, in relative_import.<locals>.__getattr__(import_name)
#      36     class_module = importlib.import_module(rel_module, parent_name)
#      37     return getattr(class_module, class_name)
# ---> 39 raise AttributeError(
#      40     "module {__name__!r} has no attribute {name!r}".format(
#      41         name=import_name, __name__=parent_name
#      42     )
#      43 )
#
# ...
